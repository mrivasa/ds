# %% [markdown]
# ## Finding best model and hyper parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import pandas as pd

def loadObservations(file_name):
    # Load observations from file
    observations = pd.read_csv(file_name)
    # Last column (classes)
    Y = observations.iloc[: , -1]
    # Droping lon/lat columns
    X = observations.iloc[:, 0:19]
    return X, Y

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [10,20],
            'kernel': ['rbf','linear']
        },
        'process': True  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [10,20,40,80,160],
            'criterion': ['gini','entropy','log_loss'],
            'max_features': ['auto','sqrt','log2']
        },
        'process': False  
    },
    'logistic_regression' : {
        'model': LogisticRegression(max_iter=35000),
        'params': {
            'C': [5,10],
            'solver': ['liblinear','lbfgs']
        },
        'process': True  
    },
    'naive_bayes_gaussian': {
        'model': GaussianNB(),
        'params': {},
        'process': True  
    },
    'nearest_neighbor': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [5,10],
            'weights': ['uniform','distance']
        },
        'process': True  
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini','entropy','log_loss'],
            'max_features': ['sqrt','log2']
        },
        'process': True  
    }     
}

observations_data = {
    'Balanced': "combined_joro_v2.csv",
    'Imbalanced': "combined_joro_imbalanced.csv"
}

# %%
# Tuning results
scores = []

for obs_name, file_name in observations_data.items():
    print(obs_name, file_name)
    X, Y = loadObservations(file_name)
    for model_name, mp in model_params.items():
        if mp['process'] == False:
            continue
        print(model_name)
        clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
        clf.fit(X, Y)
        scores.append({
            'obs_name': obs_name,
            'model': model_name,
            'best_score': clf.best_score_,
            'best_params': clf.best_params_
        })
    
df = pd.DataFrame(scores,columns=['obs_name','model','best_score','best_params'])
df
# Out:
# Balanced combined_joro_v2.csv
# svm
# logistic_regression
# naive_bayes_gaussian
# nearest_neighbor
# decision_tree
# Imbalanced combined_joro_imbalanced.csv
# svm
# logistic_regression
# naive_bayes_gaussian
# nearest_neighbor
# decision_tree
#      obs_name                 model  best_score  \
# 0    Balanced                   svm    0.919822
# 1    Balanced   logistic_regression    0.921193
# 2    Balanced  naive_bayes_gaussian    0.907715
# 3    Balanced      nearest_neighbor    0.942208
# 4    Balanced         decision_tree    0.943350
# 5  Imbalanced                   svm    0.969959
# 6  Imbalanced   logistic_regression    0.960390
# 7  Imbalanced  naive_bayes_gaussian    0.890087
# 8  Imbalanced      nearest_neighbor    0.979154
# 9  Imbalanced         decision_tree    0.976203
#
#                                          best_params
# 0                      {'C': 10, 'kernel': 'linear'}
# 1                    {'C': 5, 'solver': 'liblinear'}
# 2                                                 {}
# 3          {'n_neighbors': 5, 'weights': 'distance'}
# 4  {'criterion': 'log_loss', 'max_features': 'sqrt'}
# 5                         {'C': 10, 'kernel': 'rbf'}
# 6                        {'C': 5, 'solver': 'lbfgs'}
# 7                                                 {}
# 8          {'n_neighbors': 5, 'weights': 'distance'}
# 9  {'criterion': 'log_loss', 'max_features': 'sqrt'}
